# %% [markdown]
# <a href="https://colab.research.google.com/github/Rustam67/My-essay/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Привет, Google Colab!")
# Out:
# Привет, Google Colab!

# %%
# Базовые арифметические операции
a = 15
b = 4

print("Сложение:", a + b)
print("Вычитание:", a - b)
print("Умножение:", a * b)
print("Деление:", a / b)
print("Целочисленное деление:", a // b)
print("Остаток от деления:", a % b)
print("Возведение в степень:", a ** b)
# Out:
# Сложение: 19
# Вычитание: 11
# Умножение: 60
# Деление: 3.75
# Целочисленное деление: 3
# Остаток от деления: 3
# Возведение в степень: 50625

# %%
# Базовые арифметические операции
a = 15
b = 4

a = 5
b = 10.2
c = 2 + 10j
d = 'какой-то текст'

print('Тип переменной а: ',type(a))
print('Тип переменной b: ', type(b))
print('Тип переменной c: ',type(c))
print('Тип переменной d: ', type(d))
# Out:
# Тип переменной а:  <class 'int'>
# Тип переменной b:  <class 'float'>
# Тип переменной c:  <class 'complex'>
# Тип переменной d:  <class 'str'>

# %%
num1 = float(input("Введите первое число: "))
num2 = float(input("Введите второе число: "))
operator = input("Введите оператор (+, -, *, /): ")
if operator == '+':
        result = num1 + num2
elif operator == '-':
        result = num1 - num2
elif operator == '*':
        result = num1 * num2
elif operator == '/':
    if num2 != 0:
            result = num1 / num2
    else:
            result = "Ошибка: деление на ноль"
    print(f"Результат: {result}")
# Out:
# Введите первое число: 10
# Введите второе число: 100
# Введите оператор (+, -, *, /): 88
